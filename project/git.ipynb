# %%
# !pwd

import pandas
from google.colab import drive
drive.mount('/content/drive', force_remount=True) 
#where you want to put
# %cd /content/drive/MyDrive/ML_project
# Out:
# /content
# Mounted at /content/drive
# /content/drive/MyDrive/ML_project

# %%
#git clone https://YOURTOKEN@github.com/ahbagheri01/ML_Project.git
# %cd ML_Project/
# Out:
# /content/drive/MyDrive/ML_project/ML_Project

# %%
# !git config --global user.email "ahbagheri01@gmail.com"
# !git config --global user.name "ahbagheri01"

# %%
# !git add --all

# %%
# !git commit -m "added dataset"
# Out:
# [main fad7fcf] added dataset
#  2 files changed, 100002 insertions(+), 1 deletion(-)
#  create mode 100644 datasets/train_dataset.csv
#  rewrite git.ipynb (97%)

# %%
# !git push
# Out:
# To https://github.com/ahbagheri01/ML_Project.git
#  ! [rejected]        main -> main (fetch first)
# error: failed to push some refs to 'https://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@github.com/ahbagheri01/ML_Project.git'
# hint: Updates were rejected because the remote contains work that you do
# hint: not have locally. This is usually caused by another repository pushing
# hint: to the same ref. You may want to first integrate the remote changes
# hint: (e.g., 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.
